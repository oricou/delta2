# %%
import pandas as pd
import re
import numpy as np

# %%
df = pd.read_csv('annual-number-of-deaths-by-cause.csv')

# %%
df.head()
# Out:
#         Entity Code  Year Number of executions (Amnesty International)  \
# 0  Afghanistan  AFG  2007                                           15
# 1  Afghanistan  AFG  2008                                           17
# 2  Afghanistan  AFG  2009                                            0
# 3  Afghanistan  AFG  2011                                            2
# 4  Afghanistan  AFG  2012                                           14
#
#    Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# 0                                             2933.0
# 1                                             2731.0
# 2                                             2460.0
# 3                                             2327.0
# 4                                             2254.0
#
#    Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)  \
# 0                                             1402.0
# 1                                             1424.0
# ...

# %%
lst = list(df)

for i in range(len(lst)):
    e = lst[i]
    if 'Deaths -' in e:
        e = re.sub(r'Deaths - ([^-]+).*', r'\1', e )
        lst[i] = str(e)
        
lst[lst.index('Terrorism (deaths)')] = 'Terrorism'
        
df.columns = lst

df.head()
# Out:
#         Entity Code  Year Number of executions (Amnesty International)  \
# 0  Afghanistan  AFG  2007                                           15
# 1  Afghanistan  AFG  2008                                           17
# 2  Afghanistan  AFG  2009                                            0
# 3  Afghanistan  AFG  2011                                            2
# 4  Afghanistan  AFG  2012                                           14
#
#    Meningitis   Alzheimer's disease and other dementias   \
# 0       2933.0                                    1402.0
# 1       2731.0                                    1424.0
# 2       2460.0                                    1449.0
# 3       2327.0                                    1508.0
# 4       2254.0                                    1544.0
#
#    Parkinson's disease   Nutritional deficiencies   Malaria   Drowning   ...  \
# 0                 450.0                     2488.0     393.0     2127.0  ...
# ...

# %%
df[df.Entity == 'United States'].sort_values('Year')['Cardiovascular diseases ']
# Out:
# 6714    879646.0
# 6715    877798.0
# 6716    874992.0
# 6717    895086.0
# 6718    899691.0
# 6719    908922.0
# 6720    907009.0
# 6721    904335.0
# 6722    909266.0
# 6723    920654.0
# 6724    918346.0
# 6725    913252.0
# 6726    908753.0
# 6727    895284.0
# 6728    868245.0
# 6729    864804.0
# 6730    850549.0
# 6704    836120.0
# 6705    833165.0
# 6706    823362.0
# 6707    820215.0
# 6708    830800.0
# 6709    837102.0
# 6710    847344.0
# 6711    858443.0
# 6712    876853.0
# 6713    892268.0
# 6731    899212.0
# 6732    929375.0
# 6733    957455.0
# Name: Cardiovascular diseases , dtype: float64

# %%
df.to_csv('second.csv')

# %%
df = df.drop(['Year'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 df = df.drop(['Year'], axis=1)
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:5391, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5243 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5244 def drop(  # type: ignore[override]
#    5245     self,
#    (...)
# ...

# %%
df = df.groupby(['Entity', 'Code']).sum().reset_index()
df
# Out:
# /tmp/ipykernel_67983/1671593923.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df = df.groupby(['Entity', 'Code']).sum().reset_index()
#              Entity      Code  \
# 0       Afghanistan       AFG
# 1           Albania       ALB
# 2           Algeria       DZA
# 3    American Samoa       ASM
# 4           Andorra       AND
# ..              ...       ...
# 212           World  OWID_WRL
# 213           Yemen       YEM
# 214      Yugoslavia  OWID_YGS
# 215          Zambia       ZMB
# 216        Zimbabwe       ZWE
#
#      Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# 0                                              78666.0
# 1                                               1323.0
# 2                                              15685.0
# ...

# %%
lst = list(df)


for i in range(len(lst)):
    e = lst[i]
    if 'Deaths -' in e:
        e = re.sub(r'Deaths - ([^-]+).*', r'\1', e )
        lst[i] = str(e)
    

#lst[lst.index('Number of executions (Amnesty International)')] = 'Executions'
lst[lst.index('Terrorism (deaths)')] = 'Terrorism'
        
df.columns = lst

df.head()
# Out:
#            Entity Code  Meningitis   Alzheimer's disease and other dementias   \
# 0     Afghanistan  AFG      78666.0                                   41998.0
# 1         Albania  ALB       1323.0                                   16549.0
# 2         Algeria  DZA      15685.0                                   86914.0
# 3  American Samoa  ASM         30.0                                     143.0
# 4         Andorra  AND          0.0                                     614.0
#
#    Parkinson's disease   Nutritional deficiencies   Malaria   Drowning   \
# 0               13397.0                    71453.0   13924.0    56536.0
# 1                4491.0                      569.0       0.0     2397.0
# 2               22943.0                     7138.0      70.0    24273.0
# 3                  69.0                       60.0       0.0      120.0
# 4                 137.0                        0.0       0.0        0.0
#
# ...

# %%
#df = df.groupby('Entity', 'Code').sum().reset_index()

df['Total'] = df.sum(axis=1).astype(int)

for i in range(2, len(lst)):
    df[lst[i]] = df[lst[i]].astype(int)
# Out:
# /tmp/ipykernel_67983/4060327480.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['Total'] = df.sum(axis=1).astype(int)

# %%
df['Total'] = df.sum(axis=1)
# Out:
# /tmp/ipykernel_67983/2759960331.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['Total'] = df.sum(axis=1)

# %%
df.dtypes
# Out:
# Entity                                         object
# Code                                           object
# Meningitis                                      int64
# Alzheimer's disease and other dementias         int64
# Parkinson's disease                             int64
# Nutritional deficiencies                        int64
# Malaria                                         int64
# Drowning                                        int64
# Interpersonal violence                          int64
# Maternal disorders                              int64
# HIV/AIDS                                        int64
# Drug use disorders                              int64
# Tuberculosis                                    int64
# Cardiovascular diseases                         int64
# Lower respiratory infections                    int64
# Neonatal disorders                              int64
# Alcohol use disorders                           int64
# ...

# %%
df = df.drop(df[df.Entity == 'World'].index)

df.to_csv('dataset.csv')

# %%
df['Total'].idxmax()
# Out:
# 37

# %%
df.iloc[212]
# Out:
# Entity                                           Yemen
# Code                                               YEM
# Meningitis                                       21095
# Alzheimer's disease and other dementias          31045
# Parkinson's disease                               7188
# Nutritional deficiencies                         68939
# Malaria                                         143463
# Drowning                                         27994
# Interpersonal violence                           17918
# Maternal disorders                               53611
# HIV/AIDS                                          6276
# Drug use disorders                                3718
# Tuberculosis                                     32460
# Cardiovascular diseases                        1110837
# Lower respiratory infections                    259044
# Neonatal disorders                              729558
# Alcohol use disorders                             1590
# ...

# %%
df[df['Entity'] == 'France']
# Out:
#     Entity Code  Meningitis   Alzheimer's disease and other dementias   \
# 64  France  FRA         8975                                    882954
#
#     Parkinson's disease   Nutritional deficiencies   Malaria   Drowning   \
# 64                180197                     103810         0      31279
#
#     Interpersonal violence   Maternal disorders   ...  Poisonings   Protein  \
# 64                    21575                 2301  ...         6253    99271
#
#     Terrorism  Road injuries   Chronic respiratory diseases   \
# 64        344          217006                         607771
#
#     Cirrhosis and other chronic liver diseases   Digestive diseases   \
# 64                                       357490               839800
#
#     Fire, heat, and hot substances   Acute hepatitis      Total
# 64                            24380               754  30188252
#
# [1 rows x 35 columns]
